# %%
headers = ({'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'})

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://www.arabam.com/ikinci-el/otomobil/fiat-egea?take=50&page="
car_data = []

for page_number in range(1, 51):
    url = base_url + str(page_number)
    data = requests.get(url).text
    soup = BeautifulSoup(data, 'html.parser')
    listings = soup.find_all('tr', class_='listing-list-item should-hover bg-white')
    for listing in listings:
        model = listing.find('div', class_='listing-text-new').text
        year = listing.find('td', class_='listing-text').text.strip()
        kilometers = listing.find_all('td', class_='listing-text')[1].text.strip()
        color = listing.find_all('td', class_='listing-text')[2].text.strip()
        price = listing.find('span', class_='db no-wrap listing-price').text.strip()
            
        location = listing.find('span', class_='').text + " - " + listing.find_all('span', class_='')[1].text

        car_data.append([model, year, kilometers, color, price, location])

# %%
listing
# Out:
# <tr class="listing-list-item should-hover bg-white" id="listing25712449">
# <td class="pr" style="width: 200px;">
# <div class="fade-out-content-wrapper">
# <a class="smallest-text-minus ovh" href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self">
# <img alt="Sahibinden Fiat Egea 1.3 Multijet Urban Plus 2020 Model" class="listing-image" data-src="https://arbstorage.mncdn.com/ilanfotograflari/2024/06/22/25712449/13d89b60-e69b-417c-86c2-87c210b87974_image_for_silan_25712449_240x180.jpg" height="90" src="https://arbimg1.mncdn.com/ilanfotograflari/noImage/01/01/1/noimage5_160x120.jpg" width="120"/>
# </a>
# </div>
# <div class="item-overlay overlay-25712449"></div>
# </td>
# <td class="listing-modelname pr">
# <h3 class="crop-after">
# <div class="listing-text-new word-break val-middle color-black2018">Fiat Egea 1.3 Multijet Urban Plus</div>
# </h3>
# <div class="item-overlay overlay-25712449"></div>
# <a class="link-overlay" href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self"></a>
# </td>
# <td class="horizontal-half-padder-minus pr">
# <h4 class="crop-after crop-after-40 odd-ca40">
# <div class="listing-text-new word-break listing-title-lines" ng-non-bindable="">Sahibinden Fiat Egea 1.3 Multijet Urban Plus 2020 Model</div>
# </h4>
# <div class="label-container">
# </div>
# <div class="item-overlay overlay-25712449"></div>
# <a class="link-overlay" href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self"></a>
# </td>
# <td class="listing-text">
# <div class="fade-out-content-wrapper">
# <a class="" href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self">2020</a>
# </div>
# <div class="item-overlay overlay-25712449"></div>
# </td>
# <td class="listing-text">
# <div class="fade-out-content-wrapper">
# <a class="" href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self">55.000 </a>
# </div>
# <div class="item-overlay overlay-25712449"></div>
# </td>
# <td class="listing-text">
# <div class="fade-out-content-wrapper">
# <a class="" href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self">Kırmızı</a>
# </div>
# <div class="item-overlay overlay-25712449"></div>
# </td>
# <td class="">
# <div class="fade-out-content-wrapper">
# <a href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self">
# <span class="db no-wrap listing-price" itemscope="">
#                         760.000 TL
#                     </span>
# </a>
# </div>
# <div class="item-overlay overlay-25712449"></div>
# </td>
# <td class="listing-text tac">
# <div class="fade-out-content-wrapper">
# <a class="" href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self">23 Haziran 2024</a>
# </div>
# <div class="item-overlay overlay-25712449"></div>
# </td>
# <td class="listing-text">
# <div style="display:flex;justify-content:center;align-items:center;height:81px">
# <div class="fade-out-content-wrapper">
# <a class="" href="/ilan/sahibinden-satilik-fiat-egea-1-3-multijet-urban-plus/sahibinden-fiat-egea-1-3-multijet-urban-plus-2020-model/25712449" onclick="dataLayerClick('1850' , '49')" target="_self">
# <span class="" title="Eskişehir">Eskişehir</span>
# <span class="" title="Odunpazarı">Odunpazarı</span>
# </a>
# </div>
# <div class="visible-on-parent-hover toolbox-wrapper">
# <span class="toolbox-item" id="compare-container25712449" onclick="handleClickComparePopup({id: '25712449',price: '760.000 TL', image: 'https://arbstorage.mncdn.com/ilanfotograflari/2024/06/22/25712449/13d89b60-e69b-417c-86c2-87c210b87974_image_for_silan_25712449_120x90.jpg', mainCategoryId: '18', modelName: 'Fiat Egea 1.3 Multijet Urban Plus', title: 'Sahibinden Fiat Egea 1.3 Multijet Urban Plus 2020 Model'}, event);event.stopPropagation();">
# <i class="icon-arabam-karsilastir"></i>
# <span class="pl4" id="add-compare25712449">Karşılaştır</span>
# <span class="pl4 dn" id="remove-compare25712449">Karşılaştırmadan Çıkar</span>
# </span>
# <span class="toolbox-item" id="favorite-container25712449">
# <svg class="icon" height="16" width="16">
# <use xlink:href="#arabam-list-star"></use>
# </svg>
# <span class="pl4 dn" id="add-favorite25712449" onclick="removeFromFavorite(25712449, event);">Favorilerimde</span>
# <span class="pl4" id="remove-favorite25712449" onclick="handleClickAddFavorite(25712449, event);">Favoriye Ekle</span>
# </span>
# <span class="toolbox-item" id="hide-25712449" onclick="toggleHide(25712449, event);">
# <svg class="icon" height="16" width="16">
# <use xlink:href="#arabam-list-eye"></use>
# </svg>
# <span class="pl4">Gizle</span>
# </span>
# <span class="toolbox-item dn" id="show-25712449">
# <svg class="icon" height="16" width="16">
# <use xlink:href="#arabam-list-eye"></use>
# </svg>
# <span class="pl4">Göster</span>
# </span>
# </div>
# <div class="item-overlay overlay-25712449" onclick="toggleShow(25712449, event);" style="cursor: pointer;">
# <span class="toolbox-item">
# <svg class="icon" height="16" width="16">
# <use xlink:href="#arabam-list-eye"></use>
# </svg>
# <span class="pl4">Göster</span>
# </span>
# </div>
# </div>
# </td>
# </tr>

# %%
import pandas as pd
df = pd.DataFrame(car_data, columns=['Model', 'Year', 'Kilometers', 'Color', 'Price', 'Location'])
df
# Out:
#                                   Model  Year Kilometers           Color  \
# 0         Fiat Egea 1.4 Fire Urban Plus  2020     37.000           Beyaz
# 1           Fiat Egea 1.3 Multijet Easy  2020     63.000           Beyaz
# 2      Fiat Egea 1.3 Multijet Easy Plus  2023     17.000  Mavi (metalik)
# 3     Fiat Egea 1.6 Multijet Urban Plus  2020    101.000            Füme
# 4           Fiat Egea 1.3 Multijet Easy  2023     50.000           Beyaz
# ...                                 ...   ...        ...             ...
# 2488  Fiat Egea 1.3 Multijet Urban Plus  2019     35.000           Beyaz
# 2489        Fiat Egea 1.6 E-Torq Lounge  2016    165.000           Beyaz
# 2490        Fiat Egea 1.6 E-Torq Mirror  2019    143.000           Beyaz
# 2491        Fiat Egea 1.3 Multijet Easy  2020     38.500           Beyaz
# 2492        Fiat Egea 1.3 Multijet Easy  2022      8.500           Beyaz
#
#            Price                      Location
# 0     665.000 TL               Kocaeli - Gebze
# 1     710.000 TL             İstanbul - Pendik
# 2     840.000 TL              Ankara - Çankaya
# 3     789.950 TL            İstanbul - Üsküdar
# 4     790.000 TL           Kayseri - Kocasinan
# ...          ...                           ...
# 2488  740.000 TL               Elazığ - Merkez
# 2489  620.000 TL          Şanlıurfa - Haliliye
# 2490  805.000 TL           Kayseri - Melikgazi
# 2491  659.000 TL             Adıyaman - Merkez
# 2492  875.000 TL  Kahramanmaraş - Dulkadiroğlu
#
# [2493 rows x 6 columns]

# %%
col = df["Model"].str.split(" ", 1, expand=True).rename({0:"Car Brand", 1:"CarModel"}, axis = 1)

# %%
df = df.join([col])

# %%
df = df.drop("Model", axis = 1)

# %%
df.isnull().sum()
# Out:
# Year          0
# Kilometers    0
# Color         0
# Price         0
# Location      0
# Car Brand     0
# CarModel      0
# dtype: int64

# %%
df
# Out:
#       Year Kilometers           Color       Price  \
# 0     2020     37.000           Beyaz  665.000 TL
# 1     2020     63.000           Beyaz  710.000 TL
# 2     2023     17.000  Mavi (metalik)  840.000 TL
# 3     2020    101.000            Füme  789.950 TL
# 4     2023     50.000           Beyaz  790.000 TL
# ...    ...        ...             ...         ...
# 2488  2019     35.000           Beyaz  740.000 TL
# 2489  2016    165.000           Beyaz  620.000 TL
# 2490  2019    143.000           Beyaz  805.000 TL
# 2491  2020     38.500           Beyaz  659.000 TL
# 2492  2022      8.500           Beyaz  875.000 TL
#
#                           Location Car Brand                      CarModel
# 0                  Kocaeli - Gebze      Fiat      Egea 1.4 Fire Urban Plus
# 1                İstanbul - Pendik      Fiat        Egea 1.3 Multijet Easy
# 2                 Ankara - Çankaya      Fiat   Egea 1.3 Multijet Easy Plus
# 3               İstanbul - Üsküdar      Fiat  Egea 1.6 Multijet Urban Plus
# 4              Kayseri - Kocasinan      Fiat        Egea 1.3 Multijet Easy
# ...                            ...       ...                           ...
# 2488               Elazığ - Merkez      Fiat  Egea 1.3 Multijet Urban Plus
# 2489          Şanlıurfa - Haliliye      Fiat        Egea 1.6 E-Torq Lounge
# 2490           Kayseri - Melikgazi      Fiat        Egea 1.6 E-Torq Mirror
# 2491             Adıyaman - Merkez      Fiat        Egea 1.3 Multijet Easy
# 2492  Kahramanmaraş - Dulkadiroğlu      Fiat        Egea 1.3 Multijet Easy
#
# [2493 rows x 7 columns]

# %%
col2 = df.CarModel.str.split(" ", 1, expand=True).rename({0:"Model", 1:"Engine"}, axis = 1)

# %%
df = df.join(col2)

# %%
df
# Out:
#       Year Kilometers           Color       Price  \
# 0     2020     37.000           Beyaz  665.000 TL
# 1     2020     63.000           Beyaz  710.000 TL
# 2     2023     17.000  Mavi (metalik)  840.000 TL
# 3     2020    101.000            Füme  789.950 TL
# 4     2023     50.000           Beyaz  790.000 TL
# ...    ...        ...             ...         ...
# 2488  2019     35.000           Beyaz  740.000 TL
# 2489  2016    165.000           Beyaz  620.000 TL
# 2490  2019    143.000           Beyaz  805.000 TL
# 2491  2020     38.500           Beyaz  659.000 TL
# 2492  2022      8.500           Beyaz  875.000 TL
#
#                           Location Car Brand                      CarModel  \
# 0                  Kocaeli - Gebze      Fiat      Egea 1.4 Fire Urban Plus
# 1                İstanbul - Pendik      Fiat        Egea 1.3 Multijet Easy
# 2                 Ankara - Çankaya      Fiat   Egea 1.3 Multijet Easy Plus
# 3               İstanbul - Üsküdar      Fiat  Egea 1.6 Multijet Urban Plus
# 4              Kayseri - Kocasinan      Fiat        Egea 1.3 Multijet Easy
# ...                            ...       ...                           ...
# 2488               Elazığ - Merkez      Fiat  Egea 1.3 Multijet Urban Plus
# 2489          Şanlıurfa - Haliliye      Fiat        Egea 1.6 E-Torq Lounge
# 2490           Kayseri - Melikgazi      Fiat        Egea 1.6 E-Torq Mirror
# 2491             Adıyaman - Merkez      Fiat        Egea 1.3 Multijet Easy
# 2492  Kahramanmaraş - Dulkadiroğlu      Fiat        Egea 1.3 Multijet Easy
#
#      Model                   Engine
# 0     Egea      1.4 Fire Urban Plus
# 1     Egea        1.3 Multijet Easy
# 2     Egea   1.3 Multijet Easy Plus
# 3     Egea  1.6 Multijet Urban Plus
# 4     Egea        1.3 Multijet Easy
# ...    ...                      ...
# 2488  Egea  1.3 Multijet Urban Plus
# 2489  Egea        1.6 E-Torq Lounge
# 2490  Egea        1.6 E-Torq Mirror
# 2491  Egea        1.3 Multijet Easy
# 2492  Egea        1.3 Multijet Easy
#
# [2493 rows x 9 columns]

# %%
df = df.drop('CarModel', axis = 1)

# %%
col3 = df.Price.str.split(" ", 1, expand = True).rename({0:"Price1", 1:"Currency"}, axis = 1)

# %%
df = df.join(col3)
df
# Out:
#       Year Kilometers           Color       Price  \
# 0     2020     37.000           Beyaz  665.000 TL
# 1     2020     63.000           Beyaz  710.000 TL
# 2     2023     17.000  Mavi (metalik)  840.000 TL
# 3     2020    101.000            Füme  789.950 TL
# 4     2023     50.000           Beyaz  790.000 TL
# ...    ...        ...             ...         ...
# 2488  2019     35.000           Beyaz  740.000 TL
# 2489  2016    165.000           Beyaz  620.000 TL
# 2490  2019    143.000           Beyaz  805.000 TL
# 2491  2020     38.500           Beyaz  659.000 TL
# 2492  2022      8.500           Beyaz  875.000 TL
#
#                           Location Car Brand Model                   Engine  \
# 0                  Kocaeli - Gebze      Fiat  Egea      1.4 Fire Urban Plus
# 1                İstanbul - Pendik      Fiat  Egea        1.3 Multijet Easy
# 2                 Ankara - Çankaya      Fiat  Egea   1.3 Multijet Easy Plus
# 3               İstanbul - Üsküdar      Fiat  Egea  1.6 Multijet Urban Plus
# 4              Kayseri - Kocasinan      Fiat  Egea        1.3 Multijet Easy
# ...                            ...       ...   ...                      ...
# 2488               Elazığ - Merkez      Fiat  Egea  1.3 Multijet Urban Plus
# 2489          Şanlıurfa - Haliliye      Fiat  Egea        1.6 E-Torq Lounge
# 2490           Kayseri - Melikgazi      Fiat  Egea        1.6 E-Torq Mirror
# 2491             Adıyaman - Merkez      Fiat  Egea        1.3 Multijet Easy
# 2492  Kahramanmaraş - Dulkadiroğlu      Fiat  Egea        1.3 Multijet Easy
#
#        Price1 Currency
# 0     665.000       TL
# 1     710.000       TL
# 2     840.000       TL
# 3     789.950       TL
# 4     790.000       TL
# ...       ...      ...
# 2488  740.000       TL
# 2489  620.000       TL
# 2490  805.000       TL
# 2491  659.000       TL
# 2492  875.000       TL
#
# [2493 rows x 10 columns]

# %%
if "Price" in df.columns:
    df = df.drop("Price", axis=1)
else:
    print("Column 'Price' not found in the dataset.")

print(df.head())
# Out:
#    Year Kilometers           Color             Location Car Brand Model  \
# 0  2020     37.000           Beyaz      Kocaeli - Gebze      Fiat  Egea
# 1  2020     63.000           Beyaz    İstanbul - Pendik      Fiat  Egea
# 2  2023     17.000  Mavi (metalik)     Ankara - Çankaya      Fiat  Egea
# 3  2020    101.000            Füme   İstanbul - Üsküdar      Fiat  Egea
# 4  2023     50.000           Beyaz  Kayseri - Kocasinan      Fiat  Egea
#
#                     Engine   Price1 Currency
# 0      1.4 Fire Urban Plus  665.000       TL
# 1        1.3 Multijet Easy  710.000       TL
# 2   1.3 Multijet Easy Plus  840.000       TL
# 3  1.6 Multijet Urban Plus  789.950       TL
# 4        1.3 Multijet Easy  790.000       TL

# %%
col4 = df.Location.str.split(" ", 1, expand = True).rename({0:"City", 1:"District"}, axis = 1)
col4
# Out:
#                City        District
# 0           Kocaeli         - Gebze
# 1          İstanbul        - Pendik
# 2            Ankara       - Çankaya
# 3          İstanbul       - Üsküdar
# 4           Kayseri     - Kocasinan
# ...             ...             ...
# 2488         Elazığ        - Merkez
# 2489      Şanlıurfa      - Haliliye
# 2490        Kayseri     - Melikgazi
# 2491       Adıyaman        - Merkez
# 2492  Kahramanmaraş  - Dulkadiroğlu
#
# [2493 rows x 2 columns]

# %%
df = df.join(col4)

# %%
df = df.drop("Location", axis = 1)

# %%
df['District'] = df['District'].str.replace("-", " ")

# %%
df
# Out:
#       Year Kilometers           Color Car Brand Model  \
# 0     2020     37.000           Beyaz      Fiat  Egea
# 1     2020     63.000           Beyaz      Fiat  Egea
# 2     2023     17.000  Mavi (metalik)      Fiat  Egea
# 3     2020    101.000            Füme      Fiat  Egea
# 4     2023     50.000           Beyaz      Fiat  Egea
# ...    ...        ...             ...       ...   ...
# 2488  2019     35.000           Beyaz      Fiat  Egea
# 2489  2016    165.000           Beyaz      Fiat  Egea
# 2490  2019    143.000           Beyaz      Fiat  Egea
# 2491  2020     38.500           Beyaz      Fiat  Egea
# 2492  2022      8.500           Beyaz      Fiat  Egea
#
#                        Engine   Price1 Currency           City        District
# 0         1.4 Fire Urban Plus  665.000       TL        Kocaeli           Gebze
# 1           1.3 Multijet Easy  710.000       TL       İstanbul          Pendik
# 2      1.3 Multijet Easy Plus  840.000       TL         Ankara         Çankaya
# 3     1.6 Multijet Urban Plus  789.950       TL       İstanbul         Üsküdar
# 4           1.3 Multijet Easy  790.000       TL        Kayseri       Kocasinan
# ...                       ...      ...      ...            ...             ...
# 2488  1.3 Multijet Urban Plus  740.000       TL         Elazığ          Merkez
# 2489        1.6 E-Torq Lounge  620.000       TL      Şanlıurfa        Haliliye
# 2490        1.6 E-Torq Mirror  805.000       TL        Kayseri       Melikgazi
# 2491        1.3 Multijet Easy  659.000       TL       Adıyaman          Merkez
# 2492        1.3 Multijet Easy  875.000       TL  Kahramanmaraş    Dulkadiroğlu
#
# [2493 rows x 10 columns]

# %%
df.rename(columns = {"Price1":"Price"}, inplace = True)

# %%
df['Year'] = df['Year'].astype(int)

# %%
df['Kilometers'] = df['Kilometers'].str.replace('.', '')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14368\2414687831.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Kilometers'] = df['Kilometers'].str.replace('.', '')

# %%
df['Kilometers'] = df['Kilometers'].astype(int)

# %%
type(df['Kilometers'][0])
# Out:
# numpy.int32

# %%
df = df.drop("Currency", axis = 1)

# %%
df
# Out:
#       Year  Kilometers           Color Car Brand Model  \
# 0     2020       37000           Beyaz      Fiat  Egea
# 1     2020       63000           Beyaz      Fiat  Egea
# 2     2023       17000  Mavi (metalik)      Fiat  Egea
# 3     2020      101000            Füme      Fiat  Egea
# 4     2023       50000           Beyaz      Fiat  Egea
# ...    ...         ...             ...       ...   ...
# 2488  2019       35000           Beyaz      Fiat  Egea
# 2489  2016      165000           Beyaz      Fiat  Egea
# 2490  2019      143000           Beyaz      Fiat  Egea
# 2491  2020       38500           Beyaz      Fiat  Egea
# 2492  2022        8500           Beyaz      Fiat  Egea
#
#                        Engine    Price           City        District
# 0         1.4 Fire Urban Plus  665.000        Kocaeli           Gebze
# 1           1.3 Multijet Easy  710.000       İstanbul          Pendik
# 2      1.3 Multijet Easy Plus  840.000         Ankara         Çankaya
# 3     1.6 Multijet Urban Plus  789.950       İstanbul         Üsküdar
# 4           1.3 Multijet Easy  790.000        Kayseri       Kocasinan
# ...                       ...      ...            ...             ...
# 2488  1.3 Multijet Urban Plus  740.000         Elazığ          Merkez
# 2489        1.6 E-Torq Lounge  620.000      Şanlıurfa        Haliliye
# 2490        1.6 E-Torq Mirror  805.000        Kayseri       Melikgazi
# 2491        1.3 Multijet Easy  659.000       Adıyaman          Merkez
# 2492        1.3 Multijet Easy  875.000  Kahramanmaraş    Dulkadiroğlu
#
# [2493 rows x 9 columns]

# %%
col6 = df['Engine'].str.split(' ', n=1, expand=True).rename({0: 'Engine1', 1: 'Devami'}, axis=1)
col6
# Out:
#      Engine1               Devami
# 0        1.4      Fire Urban Plus
# 1        1.3        Multijet Easy
# 2        1.3   Multijet Easy Plus
# 3        1.6  Multijet Urban Plus
# 4        1.3        Multijet Easy
# ...      ...                  ...
# 2488     1.3  Multijet Urban Plus
# 2489     1.6        E-Torq Lounge
# 2490     1.6        E-Torq Mirror
# 2491     1.3        Multijet Easy
# 2492     1.3        Multijet Easy
#
# [2493 rows x 2 columns]

# %%
df = df.join(col6)

# %%
df
# Out:
#       Year  Kilometers           Color Car Brand Model  \
# 0     2020       37000           Beyaz      Fiat  Egea
# 1     2020       63000           Beyaz      Fiat  Egea
# 2     2023       17000  Mavi (metalik)      Fiat  Egea
# 3     2020      101000            Füme      Fiat  Egea
# 4     2023       50000           Beyaz      Fiat  Egea
# ...    ...         ...             ...       ...   ...
# 2488  2019       35000           Beyaz      Fiat  Egea
# 2489  2016      165000           Beyaz      Fiat  Egea
# 2490  2019      143000           Beyaz      Fiat  Egea
# 2491  2020       38500           Beyaz      Fiat  Egea
# 2492  2022        8500           Beyaz      Fiat  Egea
#
#                        Engine    Price           City        District Engine1  \
# 0         1.4 Fire Urban Plus  665.000        Kocaeli           Gebze     1.4
# 1           1.3 Multijet Easy  710.000       İstanbul          Pendik     1.3
# 2      1.3 Multijet Easy Plus  840.000         Ankara         Çankaya     1.3
# 3     1.6 Multijet Urban Plus  789.950       İstanbul         Üsküdar     1.6
# 4           1.3 Multijet Easy  790.000        Kayseri       Kocasinan     1.3
# ...                       ...      ...            ...             ...     ...
# 2488  1.3 Multijet Urban Plus  740.000         Elazığ          Merkez     1.3
# 2489        1.6 E-Torq Lounge  620.000      Şanlıurfa        Haliliye     1.6
# 2490        1.6 E-Torq Mirror  805.000        Kayseri       Melikgazi     1.6
# 2491        1.3 Multijet Easy  659.000       Adıyaman          Merkez     1.3
# 2492        1.3 Multijet Easy  875.000  Kahramanmaraş    Dulkadiroğlu     1.3
#
#                    Devami
# 0         Fire Urban Plus
# 1           Multijet Easy
# 2      Multijet Easy Plus
# 3     Multijet Urban Plus
# 4           Multijet Easy
# ...                   ...
# 2488  Multijet Urban Plus
# 2489        E-Torq Lounge
# 2490        E-Torq Mirror
# 2491        Multijet Easy
# 2492        Multijet Easy
#
# [2493 rows x 11 columns]

# %%
df['Engine1'] = df['Engine1'].astype(float)

# %%
df = df.drop(columns = 'Engine')

# %%
df.rename(columns = {"Engine1":"Engine"}, inplace = True)

# %%
df = df.drop(columns = 'Devami')

# %%
df['Price'] = df['Price'].str.replace('.', '').astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14368\3128332942.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df['Price'].str.replace('.', '').astype(int)

# %%
type(df['Price'][0])
# Out:
# numpy.int32

# %%
df.reset_index(drop = True, inplace = True)
df
# Out:
#       Year  Kilometers           Color Car Brand Model   Price           City  \
# 0     2020       37000           Beyaz      Fiat  Egea  665000        Kocaeli
# 1     2020       63000           Beyaz      Fiat  Egea  710000       İstanbul
# 2     2023       17000  Mavi (metalik)      Fiat  Egea  840000         Ankara
# 3     2020      101000            Füme      Fiat  Egea  789950       İstanbul
# 4     2023       50000           Beyaz      Fiat  Egea  790000        Kayseri
# ...    ...         ...             ...       ...   ...     ...            ...
# 2488  2019       35000           Beyaz      Fiat  Egea  740000         Elazığ
# 2489  2016      165000           Beyaz      Fiat  Egea  620000      Şanlıurfa
# 2490  2019      143000           Beyaz      Fiat  Egea  805000        Kayseri
# 2491  2020       38500           Beyaz      Fiat  Egea  659000       Adıyaman
# 2492  2022        8500           Beyaz      Fiat  Egea  875000  Kahramanmaraş
#
#             District  Engine
# 0              Gebze     1.4
# 1             Pendik     1.3
# 2            Çankaya     1.3
# 3            Üsküdar     1.6
# 4          Kocasinan     1.3
# ...              ...     ...
# 2488          Merkez     1.3
# 2489        Haliliye     1.6
# 2490       Melikgazi     1.6
# 2491          Merkez     1.3
# 2492    Dulkadiroğlu     1.3
#
# [2493 rows x 9 columns]

# %%
df.to_csv('car-sale-fiat-egea.csv', index = False)
