# %%
headers = ({'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'})

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://www.arabam.com/ikinci-el/otomobil/citroen?take=50&page="
car_data = []

for page_number in range(1, 51):
    url = base_url + str(page_number)
    data = requests.get(url).text
    soup = BeautifulSoup(data, 'html.parser')
    listings = soup.find_all('tr', class_='listing-list-item should-hover bg-white')
    for listing in listings:
        model = listing.find('div', class_='listing-text-new').text
        year = listing.find('td', class_='listing-text').text.strip()
        kilometers = listing.find_all('td', class_='listing-text')[1].text.strip()
        color = listing.find_all('td', class_='listing-text')[2].text.strip()
        price = listing.find('span', class_='db no-wrap listing-price').text.strip()
            
        location = listing.find('span', class_='').text + " - " + listing.find_all('span', class_='')[1].text

        car_data.append([model, year, kilometers, color, price, location])

# %%
import pandas as pd
df = pd.DataFrame(car_data, columns=['Model', 'Year', 'Kilometers', 'Color', 'Price', 'Location'])
df
# Out:
#                                     Model  Year Kilometers        Color  \
# 0          Citroen C5 1.6 e-HDi Dynamique  2011    247.000        Beyaz
# 1       Citroen C-Elysee 1.5 BlueHDi Feel  2023     29.250         Füme
# 2     Citroen C-Elysee 1.6 HDi Attraction  2016    197.000        Beyaz
# 3            Citroen C3 1.6 HDi Exclusive  2011    246.000  Gri (Gümüş)
# 4           Citroen C3 1.2 PureTech Shine  2019     80.000      Kırmızı
# ...                                   ...   ...        ...          ...
# 2441                    Citroen C4 1.6 SX  2009    253.000        Siyah
# 2442    Citroen C3 1.2 PureTech Feel Bold  2023      6.001          Gri
# 2443                  Citroen Saxo 1.4 SX  1999    194.000        Beyaz
# 2444             Citroen C5 1.6 HDi SX PK  2008    335.000          Gri
# 2445  Citroen C-Elysee 1.6 HDi Attraction  2015    207.000        Beyaz
#
#            Price               Location
# 0     579.750 TL  İstanbul - Eyüpsultan
# 1     765.000 TL     İstanbul - Üsküdar
# 2     494.000 TL        Ankara - Sincan
# 3     495.000 TL         Sivas - Merkez
# 4     745.000 TL   Ankara - Yenimahalle
# ...          ...                    ...
# 2441  450.000 TL     Ankara - Etimesgut
# 2442  795.000 TL      İzmir - Karşıyaka
# 2443  167.500 TL    İstanbul - Güngören
# 2444  430.000 TL       Ankara - Çankaya
# 2445  475.000 TL     İstanbul - Maltepe
#
# [2446 rows x 6 columns]

# %%
col = df["Model"].str.split(" ", 1, expand=True).rename({0:"Car Brand", 1:"CarModel"}, axis = 1)

# %%
df = df.join([col])

# %%
df = df.drop("Model", axis = 1)

# %%
df
# Out:
#       Year Kilometers        Color       Price               Location  \
# 0     2011    247.000        Beyaz  579.750 TL  İstanbul - Eyüpsultan
# 1     2023     29.250         Füme  765.000 TL     İstanbul - Üsküdar
# 2     2016    197.000        Beyaz  494.000 TL        Ankara - Sincan
# 3     2011    246.000  Gri (Gümüş)  495.000 TL         Sivas - Merkez
# 4     2019     80.000      Kırmızı  745.000 TL   Ankara - Yenimahalle
# ...    ...        ...          ...         ...                    ...
# 2441  2009    253.000        Siyah  450.000 TL     Ankara - Etimesgut
# 2442  2023      6.001          Gri  795.000 TL      İzmir - Karşıyaka
# 2443  1999    194.000        Beyaz  167.500 TL    İstanbul - Güngören
# 2444  2008    335.000          Gri  430.000 TL       Ankara - Çankaya
# 2445  2015    207.000        Beyaz  475.000 TL     İstanbul - Maltepe
#
#      Car Brand                     CarModel
# 0      Citroen       C5 1.6 e-HDi Dynamique
# 1      Citroen    C-Elysee 1.5 BlueHDi Feel
# 2      Citroen  C-Elysee 1.6 HDi Attraction
# 3      Citroen         C3 1.6 HDi Exclusive
# 4      Citroen        C3 1.2 PureTech Shine
# ...        ...                          ...
# 2441   Citroen                    C4 1.6 SX
# 2442   Citroen    C3 1.2 PureTech Feel Bold
# 2443   Citroen                  Saxo 1.4 SX
# 2444   Citroen             C5 1.6 HDi SX PK
# 2445   Citroen  C-Elysee 1.6 HDi Attraction
#
# [2446 rows x 7 columns]

# %%
df[["Car Brand", "CarModel", "Year", "Kilometers", "Color", "Location"]]
# Out:
#      Car Brand                     CarModel  Year Kilometers        Color  \
# 0      Citroen       C5 1.6 e-HDi Dynamique  2011    247.000        Beyaz
# 1      Citroen    C-Elysee 1.5 BlueHDi Feel  2023     29.250         Füme
# 2      Citroen  C-Elysee 1.6 HDi Attraction  2016    197.000        Beyaz
# 3      Citroen         C3 1.6 HDi Exclusive  2011    246.000  Gri (Gümüş)
# 4      Citroen        C3 1.2 PureTech Shine  2019     80.000      Kırmızı
# ...        ...                          ...   ...        ...          ...
# 2441   Citroen                    C4 1.6 SX  2009    253.000        Siyah
# 2442   Citroen    C3 1.2 PureTech Feel Bold  2023      6.001          Gri
# 2443   Citroen                  Saxo 1.4 SX  1999    194.000        Beyaz
# 2444   Citroen             C5 1.6 HDi SX PK  2008    335.000          Gri
# 2445   Citroen  C-Elysee 1.6 HDi Attraction  2015    207.000        Beyaz
#
#                    Location
# 0     İstanbul - Eyüpsultan
# 1        İstanbul - Üsküdar
# 2           Ankara - Sincan
# 3            Sivas - Merkez
# 4      Ankara - Yenimahalle
# ...                     ...
# 2441     Ankara - Etimesgut
# 2442      İzmir - Karşıyaka
# 2443    İstanbul - Güngören
# 2444       Ankara - Çankaya
# 2445     İstanbul - Maltepe
#
# [2446 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Year          0
# Kilometers    0
# Color         0
# Price         0
# Location      0
# Car Brand     0
# CarModel      0
# dtype: int64

# %%
col2 = df.CarModel.str.split(" ", 1, expand=True).rename({0:"Model", 1:"Engine"}, axis = 1)

# %%
df = df.join(col2)

# %%
df
# Out:
#       Year Kilometers        Color       Price               Location  \
# 0     2011    247.000        Beyaz  579.750 TL  İstanbul - Eyüpsultan
# 1     2023     29.250         Füme  765.000 TL     İstanbul - Üsküdar
# 2     2016    197.000        Beyaz  494.000 TL        Ankara - Sincan
# 3     2011    246.000  Gri (Gümüş)  495.000 TL         Sivas - Merkez
# 4     2019     80.000      Kırmızı  745.000 TL   Ankara - Yenimahalle
# ...    ...        ...          ...         ...                    ...
# 2441  2009    253.000        Siyah  450.000 TL     Ankara - Etimesgut
# 2442  2023      6.001          Gri  795.000 TL      İzmir - Karşıyaka
# 2443  1999    194.000        Beyaz  167.500 TL    İstanbul - Güngören
# 2444  2008    335.000          Gri  430.000 TL       Ankara - Çankaya
# 2445  2015    207.000        Beyaz  475.000 TL     İstanbul - Maltepe
#
#      Car Brand                     CarModel     Model                  Engine
# 0      Citroen       C5 1.6 e-HDi Dynamique        C5     1.6 e-HDi Dynamique
# 1      Citroen    C-Elysee 1.5 BlueHDi Feel  C-Elysee        1.5 BlueHDi Feel
# 2      Citroen  C-Elysee 1.6 HDi Attraction  C-Elysee      1.6 HDi Attraction
# 3      Citroen         C3 1.6 HDi Exclusive        C3       1.6 HDi Exclusive
# 4      Citroen        C3 1.2 PureTech Shine        C3      1.2 PureTech Shine
# ...        ...                          ...       ...                     ...
# 2441   Citroen                    C4 1.6 SX        C4                  1.6 SX
# 2442   Citroen    C3 1.2 PureTech Feel Bold        C3  1.2 PureTech Feel Bold
# 2443   Citroen                  Saxo 1.4 SX      Saxo                  1.4 SX
# 2444   Citroen             C5 1.6 HDi SX PK        C5           1.6 HDi SX PK
# 2445   Citroen  C-Elysee 1.6 HDi Attraction  C-Elysee      1.6 HDi Attraction
#
# [2446 rows x 9 columns]

# %%
df = df.drop('CarModel', axis = 1)

# %%
col3 = df.Price.str.split(" ", 1, expand = True).rename({0:"Price1", 1:"Currency"}, axis = 1)

# %%
df = df.join(col3)
df
# Out:
#       Year Kilometers        Color       Price               Location  \
# 0     2011    247.000        Beyaz  579.750 TL  İstanbul - Eyüpsultan
# 1     2023     29.250         Füme  765.000 TL     İstanbul - Üsküdar
# 2     2016    197.000        Beyaz  494.000 TL        Ankara - Sincan
# 3     2011    246.000  Gri (Gümüş)  495.000 TL         Sivas - Merkez
# 4     2019     80.000      Kırmızı  745.000 TL   Ankara - Yenimahalle
# ...    ...        ...          ...         ...                    ...
# 2441  2009    253.000        Siyah  450.000 TL     Ankara - Etimesgut
# 2442  2023      6.001          Gri  795.000 TL      İzmir - Karşıyaka
# 2443  1999    194.000        Beyaz  167.500 TL    İstanbul - Güngören
# 2444  2008    335.000          Gri  430.000 TL       Ankara - Çankaya
# 2445  2015    207.000        Beyaz  475.000 TL     İstanbul - Maltepe
#
#      Car Brand     Model                  Engine   Price1 Currency
# 0      Citroen        C5     1.6 e-HDi Dynamique  579.750       TL
# 1      Citroen  C-Elysee        1.5 BlueHDi Feel  765.000       TL
# 2      Citroen  C-Elysee      1.6 HDi Attraction  494.000       TL
# 3      Citroen        C3       1.6 HDi Exclusive  495.000       TL
# 4      Citroen        C3      1.2 PureTech Shine  745.000       TL
# ...        ...       ...                     ...      ...      ...
# 2441   Citroen        C4                  1.6 SX  450.000       TL
# 2442   Citroen        C3  1.2 PureTech Feel Bold  795.000       TL
# 2443   Citroen      Saxo                  1.4 SX  167.500       TL
# 2444   Citroen        C5           1.6 HDi SX PK  430.000       TL
# 2445   Citroen  C-Elysee      1.6 HDi Attraction  475.000       TL
#
# [2446 rows x 10 columns]

# %%
if "Price" in df.columns:
    df = df.drop("Price", axis=1)
else:
    print("Column 'Price' not found in the dataset.")

print(df.head())
# Out:
#    Year Kilometers        Color               Location Car Brand     Model  \
# 0  2011    247.000        Beyaz  İstanbul - Eyüpsultan   Citroen        C5
# 1  2023     29.250         Füme     İstanbul - Üsküdar   Citroen  C-Elysee
# 2  2016    197.000        Beyaz        Ankara - Sincan   Citroen  C-Elysee
# 3  2011    246.000  Gri (Gümüş)         Sivas - Merkez   Citroen        C3
# 4  2019     80.000      Kırmızı   Ankara - Yenimahalle   Citroen        C3
#
#                 Engine   Price1 Currency
# 0  1.6 e-HDi Dynamique  579.750       TL
# 1     1.5 BlueHDi Feel  765.000       TL
# 2   1.6 HDi Attraction  494.000       TL
# 3    1.6 HDi Exclusive  495.000       TL
# 4   1.2 PureTech Shine  745.000       TL

# %%
col4 = df.Location.str.split(" ", 1, expand = True).rename({0:"City", 1:"District"}, axis = 1)
col4
# Out:
#           City       District
# 0     İstanbul   - Eyüpsultan
# 1     İstanbul      - Üsküdar
# 2       Ankara       - Sincan
# 3        Sivas       - Merkez
# 4       Ankara  - Yenimahalle
# ...        ...            ...
# 2441    Ankara    - Etimesgut
# 2442     İzmir    - Karşıyaka
# 2443  İstanbul     - Güngören
# 2444    Ankara      - Çankaya
# 2445  İstanbul      - Maltepe
#
# [2446 rows x 2 columns]

# %%
df = df.join(col4)

# %%
df
# Out:
#       Year Kilometers        Color               Location Car Brand     Model  \
# 0     2011    247.000        Beyaz  İstanbul - Eyüpsultan   Citroen        C5
# 1     2023     29.250         Füme     İstanbul - Üsküdar   Citroen  C-Elysee
# 2     2016    197.000        Beyaz        Ankara - Sincan   Citroen  C-Elysee
# 3     2011    246.000  Gri (Gümüş)         Sivas - Merkez   Citroen        C3
# 4     2019     80.000      Kırmızı   Ankara - Yenimahalle   Citroen        C3
# ...    ...        ...          ...                    ...       ...       ...
# 2441  2009    253.000        Siyah     Ankara - Etimesgut   Citroen        C4
# 2442  2023      6.001          Gri      İzmir - Karşıyaka   Citroen        C3
# 2443  1999    194.000        Beyaz    İstanbul - Güngören   Citroen      Saxo
# 2444  2008    335.000          Gri       Ankara - Çankaya   Citroen        C5
# 2445  2015    207.000        Beyaz     İstanbul - Maltepe   Citroen  C-Elysee
#
#                       Engine   Price1 Currency      City       District
# 0        1.6 e-HDi Dynamique  579.750       TL  İstanbul   - Eyüpsultan
# 1           1.5 BlueHDi Feel  765.000       TL  İstanbul      - Üsküdar
# 2         1.6 HDi Attraction  494.000       TL    Ankara       - Sincan
# 3          1.6 HDi Exclusive  495.000       TL     Sivas       - Merkez
# 4         1.2 PureTech Shine  745.000       TL    Ankara  - Yenimahalle
# ...                      ...      ...      ...       ...            ...
# 2441                  1.6 SX  450.000       TL    Ankara    - Etimesgut
# 2442  1.2 PureTech Feel Bold  795.000       TL     İzmir    - Karşıyaka
# 2443                  1.4 SX  167.500       TL  İstanbul     - Güngören
# 2444           1.6 HDi SX PK  430.000       TL    Ankara      - Çankaya
# 2445      1.6 HDi Attraction  475.000       TL  İstanbul      - Maltepe
#
# [2446 rows x 11 columns]

# %%
df = df.drop("Location", axis = 1)

# %%
df['District'] = df['District'].str.replace("-", " ")

# %%
df
# Out:
#       Year Kilometers        Color Car Brand     Model  \
# 0     2011    247.000        Beyaz   Citroen        C5
# 1     2023     29.250         Füme   Citroen  C-Elysee
# 2     2016    197.000        Beyaz   Citroen  C-Elysee
# 3     2011    246.000  Gri (Gümüş)   Citroen        C3
# 4     2019     80.000      Kırmızı   Citroen        C3
# ...    ...        ...          ...       ...       ...
# 2441  2009    253.000        Siyah   Citroen        C4
# 2442  2023      6.001          Gri   Citroen        C3
# 2443  1999    194.000        Beyaz   Citroen      Saxo
# 2444  2008    335.000          Gri   Citroen        C5
# 2445  2015    207.000        Beyaz   Citroen  C-Elysee
#
#                       Engine   Price1 Currency      City       District
# 0        1.6 e-HDi Dynamique  579.750       TL  İstanbul     Eyüpsultan
# 1           1.5 BlueHDi Feel  765.000       TL  İstanbul        Üsküdar
# 2         1.6 HDi Attraction  494.000       TL    Ankara         Sincan
# 3          1.6 HDi Exclusive  495.000       TL     Sivas         Merkez
# 4         1.2 PureTech Shine  745.000       TL    Ankara    Yenimahalle
# ...                      ...      ...      ...       ...            ...
# 2441                  1.6 SX  450.000       TL    Ankara      Etimesgut
# 2442  1.2 PureTech Feel Bold  795.000       TL     İzmir      Karşıyaka
# 2443                  1.4 SX  167.500       TL  İstanbul       Güngören
# 2444           1.6 HDi SX PK  430.000       TL    Ankara        Çankaya
# 2445      1.6 HDi Attraction  475.000       TL  İstanbul        Maltepe
#
# [2446 rows x 10 columns]

# %%
df.rename(columns = {"Price1":"Price"}, inplace = True)

# %%
df['Year'] = df['Year'].astype(int)

# %%
df['Kilometers'] = df['Kilometers'].str.replace('.', '')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19428\2414687831.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Kilometers'] = df['Kilometers'].str.replace('.', '')

# %%
df = df.drop(df[df['Kilometers'] == '29 Şubat 2024'].index)

# %%
df = df.drop(df[df['Kilometers'] == '-'].index)

# %%
df['Kilometers'] = df['Kilometers'].astype(int)

# %%
type(df['Kilometers'][0])
# Out:
# numpy.int32

# %%
df = df.drop("Currency", axis = 1)

# %%
df
# Out:
#       Year  Kilometers        Color Car Brand     Model  \
# 0     2011      247000        Beyaz   Citroen        C5
# 1     2023       29250         Füme   Citroen  C-Elysee
# 2     2016      197000        Beyaz   Citroen  C-Elysee
# 3     2011      246000  Gri (Gümüş)   Citroen        C3
# 4     2019       80000      Kırmızı   Citroen        C3
# ...    ...         ...          ...       ...       ...
# 2441  2009      253000        Siyah   Citroen        C4
# 2442  2023        6001          Gri   Citroen        C3
# 2443  1999      194000        Beyaz   Citroen      Saxo
# 2444  2008      335000          Gri   Citroen        C5
# 2445  2015      207000        Beyaz   Citroen  C-Elysee
#
#                       Engine    Price      City       District
# 0        1.6 e-HDi Dynamique  579.750  İstanbul     Eyüpsultan
# 1           1.5 BlueHDi Feel  765.000  İstanbul        Üsküdar
# 2         1.6 HDi Attraction  494.000    Ankara         Sincan
# 3          1.6 HDi Exclusive  495.000     Sivas         Merkez
# 4         1.2 PureTech Shine  745.000    Ankara    Yenimahalle
# ...                      ...      ...       ...            ...
# 2441                  1.6 SX  450.000    Ankara      Etimesgut
# 2442  1.2 PureTech Feel Bold  795.000     İzmir      Karşıyaka
# 2443                  1.4 SX  167.500  İstanbul       Güngören
# 2444           1.6 HDi SX PK  430.000    Ankara        Çankaya
# 2445      1.6 HDi Attraction  475.000  İstanbul        Maltepe
#
# [2387 rows x 9 columns]

# %%
col6 = df['Engine'].str.split(' ', n=1, expand=True).rename({0: 'Engine1', 1: 'Devami'}, axis=1)
col6
# Out:
#      Engine1              Devami
# 0        1.6     e-HDi Dynamique
# 1        1.5        BlueHDi Feel
# 2        1.6      HDi Attraction
# 3        1.6       HDi Exclusive
# 4        1.2      PureTech Shine
# ...      ...                 ...
# 2441     1.6                  SX
# 2442     1.2  PureTech Feel Bold
# 2443     1.4                  SX
# 2444     1.6           HDi SX PK
# 2445     1.6      HDi Attraction
#
# [2387 rows x 2 columns]

# %%
df = df.join(col6)

# %%
df
# Out:
#       Year  Kilometers        Color Car Brand     Model  \
# 0     2011      247000        Beyaz   Citroen        C5
# 1     2023       29250         Füme   Citroen  C-Elysee
# 2     2016      197000        Beyaz   Citroen  C-Elysee
# 3     2011      246000  Gri (Gümüş)   Citroen        C3
# 4     2019       80000      Kırmızı   Citroen        C3
# ...    ...         ...          ...       ...       ...
# 2441  2009      253000        Siyah   Citroen        C4
# 2442  2023        6001          Gri   Citroen        C3
# 2443  1999      194000        Beyaz   Citroen      Saxo
# 2444  2008      335000          Gri   Citroen        C5
# 2445  2015      207000        Beyaz   Citroen  C-Elysee
#
#                       Engine    Price      City       District Engine1  \
# 0        1.6 e-HDi Dynamique  579.750  İstanbul     Eyüpsultan     1.6
# 1           1.5 BlueHDi Feel  765.000  İstanbul        Üsküdar     1.5
# 2         1.6 HDi Attraction  494.000    Ankara         Sincan     1.6
# 3          1.6 HDi Exclusive  495.000     Sivas         Merkez     1.6
# 4         1.2 PureTech Shine  745.000    Ankara    Yenimahalle     1.2
# ...                      ...      ...       ...            ...     ...
# 2441                  1.6 SX  450.000    Ankara      Etimesgut     1.6
# 2442  1.2 PureTech Feel Bold  795.000     İzmir      Karşıyaka     1.2
# 2443                  1.4 SX  167.500  İstanbul       Güngören     1.4
# 2444           1.6 HDi SX PK  430.000    Ankara        Çankaya     1.6
# 2445      1.6 HDi Attraction  475.000  İstanbul        Maltepe     1.6
#
#                   Devami
# 0        e-HDi Dynamique
# 1           BlueHDi Feel
# 2         HDi Attraction
# 3          HDi Exclusive
# 4         PureTech Shine
# ...                  ...
# 2441                  SX
# 2442  PureTech Feel Bold
# 2443                  SX
# 2444           HDi SX PK
# 2445      HDi Attraction
#
# [2387 rows x 11 columns]

# %%
picasso = df[df['Engine1'] == 'Picasso']
df.loc[picasso.index, 'Engine1'] = picasso.apply(lambda row: row['Devami'][:3], axis = 1)

# %%
grand = df[df['Engine1'] == 'Grand']
df.loc[grand.index, 'Engine1'] = grand.apply(lambda row: row['Devami'][8:12], axis = 1)

# %%
x = df[df['Engine1'] == 'X']
df.loc[x.index, 'Engine1'] = x.apply(lambda row: row['Devami'][:3], axis = 1)

# %%
df['Engine1'] = df['Engine1'].replace('1.5D', '1.5')

# %%
my = df[df['Engine1'] == 'My']
df.loc[my.index, 'Engine1'] = my.apply(lambda row: row['Devami'][:3], axis = 1)

# %%
df = df.drop(df[df['Engine1'] == 'Ami'].index)

# %%
df['Engine1'] = df['Engine1'].astype(float)

# %%
df
# Out:
#       Year  Kilometers        Color Car Brand     Model  \
# 0     2011      247000        Beyaz   Citroen        C5
# 1     2023       29250         Füme   Citroen  C-Elysee
# 2     2016      197000        Beyaz   Citroen  C-Elysee
# 3     2011      246000  Gri (Gümüş)   Citroen        C3
# 4     2019       80000      Kırmızı   Citroen        C3
# ...    ...         ...          ...       ...       ...
# 2441  2009      253000        Siyah   Citroen        C4
# 2442  2023        6001          Gri   Citroen        C3
# 2443  1999      194000        Beyaz   Citroen      Saxo
# 2444  2008      335000          Gri   Citroen        C5
# 2445  2015      207000        Beyaz   Citroen  C-Elysee
#
#                       Engine    Price      City       District  Engine1  \
# 0        1.6 e-HDi Dynamique  579.750  İstanbul     Eyüpsultan      1.6
# 1           1.5 BlueHDi Feel  765.000  İstanbul        Üsküdar      1.5
# 2         1.6 HDi Attraction  494.000    Ankara         Sincan      1.6
# 3          1.6 HDi Exclusive  495.000     Sivas         Merkez      1.6
# 4         1.2 PureTech Shine  745.000    Ankara    Yenimahalle      1.2
# ...                      ...      ...       ...            ...      ...
# 2441                  1.6 SX  450.000    Ankara      Etimesgut      1.6
# 2442  1.2 PureTech Feel Bold  795.000     İzmir      Karşıyaka      1.2
# 2443                  1.4 SX  167.500  İstanbul       Güngören      1.4
# 2444           1.6 HDi SX PK  430.000    Ankara        Çankaya      1.6
# 2445      1.6 HDi Attraction  475.000  İstanbul        Maltepe      1.6
#
#                   Devami
# 0        e-HDi Dynamique
# 1           BlueHDi Feel
# 2         HDi Attraction
# 3          HDi Exclusive
# 4         PureTech Shine
# ...                  ...
# 2441                  SX
# 2442  PureTech Feel Bold
# 2443                  SX
# 2444           HDi SX PK
# 2445      HDi Attraction
#
# [2384 rows x 11 columns]

# %%
df = df.drop(columns = 'Engine')

# %%
df.rename(columns = {"Engine1":"Engine"}, inplace = True)

# %%
df = df.drop(columns = 'Devami')

# %%
df
# Out:
#       Year  Kilometers        Color Car Brand     Model    Price      City  \
# 0     2011      247000        Beyaz   Citroen        C5  579.750  İstanbul
# 1     2023       29250         Füme   Citroen  C-Elysee  765.000  İstanbul
# 2     2016      197000        Beyaz   Citroen  C-Elysee  494.000    Ankara
# 3     2011      246000  Gri (Gümüş)   Citroen        C3  495.000     Sivas
# 4     2019       80000      Kırmızı   Citroen        C3  745.000    Ankara
# ...    ...         ...          ...       ...       ...      ...       ...
# 2441  2009      253000        Siyah   Citroen        C4  450.000    Ankara
# 2442  2023        6001          Gri   Citroen        C3  795.000     İzmir
# 2443  1999      194000        Beyaz   Citroen      Saxo  167.500  İstanbul
# 2444  2008      335000          Gri   Citroen        C5  430.000    Ankara
# 2445  2015      207000        Beyaz   Citroen  C-Elysee  475.000  İstanbul
#
#            District  Engine
# 0        Eyüpsultan     1.6
# 1           Üsküdar     1.5
# 2            Sincan     1.6
# 3            Merkez     1.6
# 4       Yenimahalle     1.2
# ...             ...     ...
# 2441      Etimesgut     1.6
# 2442      Karşıyaka     1.2
# 2443       Güngören     1.4
# 2444        Çankaya     1.6
# 2445        Maltepe     1.6
#
# [2384 rows x 9 columns]

# %%
df['Price'] = df['Price'].str.replace('.', '').astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19428\3128332942.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df['Price'].str.replace('.', '').astype(int)

# %%
type(df['Price'][0])
# Out:
# numpy.int32

# %%
df.reset_index(drop = True, inplace = True)
df
# Out:
#       Year  Kilometers        Color Car Brand     Model   Price      City  \
# 0     2011      247000        Beyaz   Citroen        C5  579750  İstanbul
# 1     2023       29250         Füme   Citroen  C-Elysee  765000  İstanbul
# 2     2016      197000        Beyaz   Citroen  C-Elysee  494000    Ankara
# 3     2011      246000  Gri (Gümüş)   Citroen        C3  495000     Sivas
# 4     2019       80000      Kırmızı   Citroen        C3  745000    Ankara
# ...    ...         ...          ...       ...       ...     ...       ...
# 2379  2009      253000        Siyah   Citroen        C4  450000    Ankara
# 2380  2023        6001          Gri   Citroen        C3  795000     İzmir
# 2381  1999      194000        Beyaz   Citroen      Saxo  167500  İstanbul
# 2382  2008      335000          Gri   Citroen        C5  430000    Ankara
# 2383  2015      207000        Beyaz   Citroen  C-Elysee  475000  İstanbul
#
#            District  Engine
# 0        Eyüpsultan     1.6
# 1           Üsküdar     1.5
# 2            Sincan     1.6
# 3            Merkez     1.6
# 4       Yenimahalle     1.2
# ...             ...     ...
# 2379      Etimesgut     1.6
# 2380      Karşıyaka     1.2
# 2381       Güngören     1.4
# 2382        Çankaya     1.6
# 2383        Maltepe     1.6
#
# [2384 rows x 9 columns]

# %%
df.to_csv('car-sale-citroen.csv', index = False)
