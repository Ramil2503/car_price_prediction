# %%
headers = ({'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'})

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://www.arabam.com/ikinci-el/otomobil/fiat-linea?take=50&page="
car_data = []

for page_number in range(1, 51):
    url = base_url + str(page_number)
    data = requests.get(url).text
    soup = BeautifulSoup(data, 'html.parser')
    listings = soup.find_all('tr', class_='listing-list-item should-hover bg-white')
    for listing in listings:
        model = listing.find('div', class_='listing-text-new').text
        year = listing.find('td', class_='listing-text').text.strip()
        kilometers = listing.find_all('td', class_='listing-text')[1].text.strip()
        color = listing.find_all('td', class_='listing-text')[2].text.strip()
        price = listing.find('span', class_='db no-wrap listing-price').text.strip()
            
        location = listing.find('span', class_='').text + " - " + listing.find_all('span', class_='')[1].text

        car_data.append([model, year, kilometers, color, price, location])

# %%
import pandas as pd
df = pd.DataFrame(car_data, columns=['Model', 'Year', 'Kilometers', 'Color', 'Price', 'Location'])
df
# Out:
#                                     Model  Year Kilometers        Color  \
# 0             Fiat Linea 1.3 Multijet Pop  2015    128.000        Beyaz
# 1             Fiat Linea 1.3 Multijet Pop  2017    225.000        Beyaz
# 2                 Fiat Linea 1.4 Fire Pop  2017     66.816  Gri (Gümüş)
# 3             Fiat Linea 1.3 Multijet Pop  2017    239.000        Beyaz
# 4           Fiat Linea 1.3 Multijet Urban  2016    490.000        Beyaz
# ...                                   ...   ...        ...          ...
# 2199             Fiat Linea 1.4 Fire Easy  2014     26.200        Beyaz
# 2200          Fiat Linea 1.3 Multijet Pop  2014    223.000        Beyaz
# 2201          Fiat Linea 1.3 Multijet Pop  2016    150.000        Beyaz
# 2202  Fiat Linea 1.3 Multijet Active Plus  2013    191.000        Beyaz
# 2203          Fiat Linea 1.3 Multijet Pop  2015    250.000        Beyaz
#
#            Price              Location
# 0     549.000 TL         Bolu - Merkez
# 1     550.000 TL         Bolu - Merkez
# 2     509.750 TL      Samsun - İlkadım
# 3     429.950 TL      İzmir - Gaziemir
# 4     350.000 TL   İstanbul - Bağcılar
# ...          ...                   ...
# 2199  535.000 TL   Kayseri - Melikgazi
# 2200  435.000 TL      Çankırı - Merkez
# 2201  350.000 TL       Muğla - Dalaman
# 2202  455.000 TL    Kocaeli - Çayırova
# 2203  430.000 TL  Malatya - Battalgazi
#
# [2204 rows x 6 columns]

# %%
col = df["Model"].str.split(" ", 1, expand=True).rename({0:"Car Brand", 1:"CarModel"}, axis = 1)

# %%
df = df.join([col])

# %%
df
# Out:
#                                     Model  Year Kilometers        Color  \
# 0             Fiat Linea 1.3 Multijet Pop  2015    128.000        Beyaz
# 1             Fiat Linea 1.3 Multijet Pop  2017    225.000        Beyaz
# 2                 Fiat Linea 1.4 Fire Pop  2017     66.816  Gri (Gümüş)
# 3             Fiat Linea 1.3 Multijet Pop  2017    239.000        Beyaz
# 4           Fiat Linea 1.3 Multijet Urban  2016    490.000        Beyaz
# ...                                   ...   ...        ...          ...
# 2199             Fiat Linea 1.4 Fire Easy  2014     26.200        Beyaz
# 2200          Fiat Linea 1.3 Multijet Pop  2014    223.000        Beyaz
# 2201          Fiat Linea 1.3 Multijet Pop  2016    150.000        Beyaz
# 2202  Fiat Linea 1.3 Multijet Active Plus  2013    191.000        Beyaz
# 2203          Fiat Linea 1.3 Multijet Pop  2015    250.000        Beyaz
#
#            Price              Location Car Brand  \
# 0     549.000 TL         Bolu - Merkez      Fiat
# 1     550.000 TL         Bolu - Merkez      Fiat
# 2     509.750 TL      Samsun - İlkadım      Fiat
# 3     429.950 TL      İzmir - Gaziemir      Fiat
# 4     350.000 TL   İstanbul - Bağcılar      Fiat
# ...          ...                   ...       ...
# 2199  535.000 TL   Kayseri - Melikgazi      Fiat
# 2200  435.000 TL      Çankırı - Merkez      Fiat
# 2201  350.000 TL       Muğla - Dalaman      Fiat
# 2202  455.000 TL    Kocaeli - Çayırova      Fiat
# 2203  430.000 TL  Malatya - Battalgazi      Fiat
#
#                             CarModel
# 0             Linea 1.3 Multijet Pop
# 1             Linea 1.3 Multijet Pop
# 2                 Linea 1.4 Fire Pop
# 3             Linea 1.3 Multijet Pop
# 4           Linea 1.3 Multijet Urban
# ...                              ...
# 2199             Linea 1.4 Fire Easy
# 2200          Linea 1.3 Multijet Pop
# 2201          Linea 1.3 Multijet Pop
# 2202  Linea 1.3 Multijet Active Plus
# 2203          Linea 1.3 Multijet Pop
#
# [2204 rows x 8 columns]

# %%
df = df.drop("Model", axis = 1)

# %%
df.isnull().sum()
# Out:
# Year          0
# Kilometers    0
# Color         0
# Price         0
# Location      0
# Car Brand     0
# CarModel      0
# dtype: int64

# %%
col2 = df.CarModel.str.split(" ", 1, expand=True).rename({0:"Model", 1:"Engine"}, axis = 1)

# %%
df = df.join(col2)

# %%
df
# Out:
#       Year Kilometers        Color       Price              Location  \
# 0     2015    128.000        Beyaz  549.000 TL         Bolu - Merkez
# 1     2017    225.000        Beyaz  550.000 TL         Bolu - Merkez
# 2     2017     66.816  Gri (Gümüş)  509.750 TL      Samsun - İlkadım
# 3     2017    239.000        Beyaz  429.950 TL      İzmir - Gaziemir
# 4     2016    490.000        Beyaz  350.000 TL   İstanbul - Bağcılar
# ...    ...        ...          ...         ...                   ...
# 2199  2014     26.200        Beyaz  535.000 TL   Kayseri - Melikgazi
# 2200  2014    223.000        Beyaz  435.000 TL      Çankırı - Merkez
# 2201  2016    150.000        Beyaz  350.000 TL       Muğla - Dalaman
# 2202  2013    191.000        Beyaz  455.000 TL    Kocaeli - Çayırova
# 2203  2015    250.000        Beyaz  430.000 TL  Malatya - Battalgazi
#
#      Car Brand                        CarModel  Model  \
# 0         Fiat          Linea 1.3 Multijet Pop  Linea
# 1         Fiat          Linea 1.3 Multijet Pop  Linea
# 2         Fiat              Linea 1.4 Fire Pop  Linea
# 3         Fiat          Linea 1.3 Multijet Pop  Linea
# 4         Fiat        Linea 1.3 Multijet Urban  Linea
# ...        ...                             ...    ...
# 2199      Fiat             Linea 1.4 Fire Easy  Linea
# 2200      Fiat          Linea 1.3 Multijet Pop  Linea
# 2201      Fiat          Linea 1.3 Multijet Pop  Linea
# 2202      Fiat  Linea 1.3 Multijet Active Plus  Linea
# 2203      Fiat          Linea 1.3 Multijet Pop  Linea
#
#                         Engine
# 0             1.3 Multijet Pop
# 1             1.3 Multijet Pop
# 2                 1.4 Fire Pop
# 3             1.3 Multijet Pop
# 4           1.3 Multijet Urban
# ...                        ...
# 2199             1.4 Fire Easy
# 2200          1.3 Multijet Pop
# 2201          1.3 Multijet Pop
# 2202  1.3 Multijet Active Plus
# 2203          1.3 Multijet Pop
#
# [2204 rows x 9 columns]

# %%
df = df.drop('CarModel', axis = 1)

# %%
col3 = df.Price.str.split(" ", 1, expand = True).rename({0:"Price1", 1:"Currency"}, axis = 1)

# %%
df = df.join(col3)
df
# Out:
#       Year Kilometers        Color       Price              Location  \
# 0     2015    128.000        Beyaz  549.000 TL         Bolu - Merkez
# 1     2017    225.000        Beyaz  550.000 TL         Bolu - Merkez
# 2     2017     66.816  Gri (Gümüş)  509.750 TL      Samsun - İlkadım
# 3     2017    239.000        Beyaz  429.950 TL      İzmir - Gaziemir
# 4     2016    490.000        Beyaz  350.000 TL   İstanbul - Bağcılar
# ...    ...        ...          ...         ...                   ...
# 2199  2014     26.200        Beyaz  535.000 TL   Kayseri - Melikgazi
# 2200  2014    223.000        Beyaz  435.000 TL      Çankırı - Merkez
# 2201  2016    150.000        Beyaz  350.000 TL       Muğla - Dalaman
# 2202  2013    191.000        Beyaz  455.000 TL    Kocaeli - Çayırova
# 2203  2015    250.000        Beyaz  430.000 TL  Malatya - Battalgazi
#
#      Car Brand  Model                    Engine   Price1 Currency
# 0         Fiat  Linea          1.3 Multijet Pop  549.000       TL
# 1         Fiat  Linea          1.3 Multijet Pop  550.000       TL
# 2         Fiat  Linea              1.4 Fire Pop  509.750       TL
# 3         Fiat  Linea          1.3 Multijet Pop  429.950       TL
# 4         Fiat  Linea        1.3 Multijet Urban  350.000       TL
# ...        ...    ...                       ...      ...      ...
# 2199      Fiat  Linea             1.4 Fire Easy  535.000       TL
# 2200      Fiat  Linea          1.3 Multijet Pop  435.000       TL
# 2201      Fiat  Linea          1.3 Multijet Pop  350.000       TL
# 2202      Fiat  Linea  1.3 Multijet Active Plus  455.000       TL
# 2203      Fiat  Linea          1.3 Multijet Pop  430.000       TL
#
# [2204 rows x 10 columns]

# %%
if "Price" in df.columns:
    df = df.drop("Price", axis=1)
else:
    print("Column 'Price' not found in the dataset.")

print(df.head())
# Out:
#    Year Kilometers        Color             Location Car Brand  Model  \
# 0  2015    128.000        Beyaz        Bolu - Merkez      Fiat  Linea
# 1  2017    225.000        Beyaz        Bolu - Merkez      Fiat  Linea
# 2  2017     66.816  Gri (Gümüş)     Samsun - İlkadım      Fiat  Linea
# 3  2017    239.000        Beyaz     İzmir - Gaziemir      Fiat  Linea
# 4  2016    490.000        Beyaz  İstanbul - Bağcılar      Fiat  Linea
#
#                Engine   Price1 Currency
# 0    1.3 Multijet Pop  549.000       TL
# 1    1.3 Multijet Pop  550.000       TL
# 2        1.4 Fire Pop  509.750       TL
# 3    1.3 Multijet Pop  429.950       TL
# 4  1.3 Multijet Urban  350.000       TL

# %%
col4 = df.Location.str.split(" ", 1, expand = True).rename({0:"City", 1:"District"}, axis = 1)
col4
# Out:
#           City      District
# 0         Bolu      - Merkez
# 1         Bolu      - Merkez
# 2       Samsun     - İlkadım
# 3        İzmir    - Gaziemir
# 4     İstanbul    - Bağcılar
# ...        ...           ...
# 2199   Kayseri   - Melikgazi
# 2200   Çankırı      - Merkez
# 2201     Muğla     - Dalaman
# 2202   Kocaeli    - Çayırova
# 2203   Malatya  - Battalgazi
#
# [2204 rows x 2 columns]

# %%
df = df.join(col4)

# %%
df
# Out:
#       Year Kilometers        Color              Location Car Brand  Model  \
# 0     2015    128.000        Beyaz         Bolu - Merkez      Fiat  Linea
# 1     2017    225.000        Beyaz         Bolu - Merkez      Fiat  Linea
# 2     2017     66.816  Gri (Gümüş)      Samsun - İlkadım      Fiat  Linea
# 3     2017    239.000        Beyaz      İzmir - Gaziemir      Fiat  Linea
# 4     2016    490.000        Beyaz   İstanbul - Bağcılar      Fiat  Linea
# ...    ...        ...          ...                   ...       ...    ...
# 2199  2014     26.200        Beyaz   Kayseri - Melikgazi      Fiat  Linea
# 2200  2014    223.000        Beyaz      Çankırı - Merkez      Fiat  Linea
# 2201  2016    150.000        Beyaz       Muğla - Dalaman      Fiat  Linea
# 2202  2013    191.000        Beyaz    Kocaeli - Çayırova      Fiat  Linea
# 2203  2015    250.000        Beyaz  Malatya - Battalgazi      Fiat  Linea
#
#                         Engine   Price1 Currency      City      District
# 0             1.3 Multijet Pop  549.000       TL      Bolu      - Merkez
# 1             1.3 Multijet Pop  550.000       TL      Bolu      - Merkez
# 2                 1.4 Fire Pop  509.750       TL    Samsun     - İlkadım
# 3             1.3 Multijet Pop  429.950       TL     İzmir    - Gaziemir
# 4           1.3 Multijet Urban  350.000       TL  İstanbul    - Bağcılar
# ...                        ...      ...      ...       ...           ...
# 2199             1.4 Fire Easy  535.000       TL   Kayseri   - Melikgazi
# 2200          1.3 Multijet Pop  435.000       TL   Çankırı      - Merkez
# 2201          1.3 Multijet Pop  350.000       TL     Muğla     - Dalaman
# 2202  1.3 Multijet Active Plus  455.000       TL   Kocaeli    - Çayırova
# 2203          1.3 Multijet Pop  430.000       TL   Malatya  - Battalgazi
#
# [2204 rows x 11 columns]

# %%
df = df.drop("Location", axis = 1)

# %%
df['District'] = df['District'].str.replace("-", " ")

# %%
df
# Out:
#       Year Kilometers        Color Car Brand  Model                    Engine  \
# 0     2015    128.000        Beyaz      Fiat  Linea          1.3 Multijet Pop
# 1     2017    225.000        Beyaz      Fiat  Linea          1.3 Multijet Pop
# 2     2017     66.816  Gri (Gümüş)      Fiat  Linea              1.4 Fire Pop
# 3     2017    239.000        Beyaz      Fiat  Linea          1.3 Multijet Pop
# 4     2016    490.000        Beyaz      Fiat  Linea        1.3 Multijet Urban
# ...    ...        ...          ...       ...    ...                       ...
# 2199  2014     26.200        Beyaz      Fiat  Linea             1.4 Fire Easy
# 2200  2014    223.000        Beyaz      Fiat  Linea          1.3 Multijet Pop
# 2201  2016    150.000        Beyaz      Fiat  Linea          1.3 Multijet Pop
# 2202  2013    191.000        Beyaz      Fiat  Linea  1.3 Multijet Active Plus
# 2203  2015    250.000        Beyaz      Fiat  Linea          1.3 Multijet Pop
#
#        Price1 Currency      City      District
# 0     549.000       TL      Bolu        Merkez
# 1     550.000       TL      Bolu        Merkez
# 2     509.750       TL    Samsun       İlkadım
# 3     429.950       TL     İzmir      Gaziemir
# 4     350.000       TL  İstanbul      Bağcılar
# ...       ...      ...       ...           ...
# 2199  535.000       TL   Kayseri     Melikgazi
# 2200  435.000       TL   Çankırı        Merkez
# 2201  350.000       TL     Muğla       Dalaman
# 2202  455.000       TL   Kocaeli      Çayırova
# 2203  430.000       TL   Malatya    Battalgazi
#
# [2204 rows x 10 columns]

# %%
df.rename(columns = {"Price1":"Price"}, inplace = True)

# %%
df['Year'] = df['Year'].astype(int)

# %%
df['Kilometers'] = df['Kilometers'].str.replace('.', '')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15876\2414687831.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Kilometers'] = df['Kilometers'].str.replace('.', '')

# %%
df['Kilometers'] = df['Kilometers'].astype(int)

# %%
type(df['Kilometers'][0])
# Out:
# numpy.int32

# %%
df = df.drop("Currency", axis = 1)

# %%
df
# Out:
#       Year  Kilometers        Color Car Brand  Model  \
# 0     2015      128000        Beyaz      Fiat  Linea
# 1     2017      225000        Beyaz      Fiat  Linea
# 2     2017       66816  Gri (Gümüş)      Fiat  Linea
# 3     2017      239000        Beyaz      Fiat  Linea
# 4     2016      490000        Beyaz      Fiat  Linea
# ...    ...         ...          ...       ...    ...
# 2199  2014       26200        Beyaz      Fiat  Linea
# 2200  2014      223000        Beyaz      Fiat  Linea
# 2201  2016      150000        Beyaz      Fiat  Linea
# 2202  2013      191000        Beyaz      Fiat  Linea
# 2203  2015      250000        Beyaz      Fiat  Linea
#
#                         Engine    Price      City      District
# 0             1.3 Multijet Pop  549.000      Bolu        Merkez
# 1             1.3 Multijet Pop  550.000      Bolu        Merkez
# 2                 1.4 Fire Pop  509.750    Samsun       İlkadım
# 3             1.3 Multijet Pop  429.950     İzmir      Gaziemir
# 4           1.3 Multijet Urban  350.000  İstanbul      Bağcılar
# ...                        ...      ...       ...           ...
# 2199             1.4 Fire Easy  535.000   Kayseri     Melikgazi
# 2200          1.3 Multijet Pop  435.000   Çankırı        Merkez
# 2201          1.3 Multijet Pop  350.000     Muğla       Dalaman
# 2202  1.3 Multijet Active Plus  455.000   Kocaeli      Çayırova
# 2203          1.3 Multijet Pop  430.000   Malatya    Battalgazi
#
# [2204 rows x 9 columns]

# %%
col6 = df['Engine'].str.split(' ', n=1, expand=True).rename({0: 'Engine1', 1: 'Devami'}, axis=1)
col6
# Out:
#      Engine1                Devami
# 0        1.3          Multijet Pop
# 1        1.3          Multijet Pop
# 2        1.4              Fire Pop
# 3        1.3          Multijet Pop
# 4        1.3        Multijet Urban
# ...      ...                   ...
# 2199     1.4             Fire Easy
# 2200     1.3          Multijet Pop
# 2201     1.3          Multijet Pop
# 2202     1.3  Multijet Active Plus
# 2203     1.3          Multijet Pop
#
# [2204 rows x 2 columns]

# %%
df = df.join(col6)

# %%
df['Engine1'] = df['Engine1'].astype(float)

# %%
df = df.drop(columns = 'Engine')

# %%
df.rename(columns = {"Engine1":"Engine"}, inplace = True)

# %%
df = df.drop(columns = 'Devami')

# %%
df['Price'] = df['Price'].str.replace('.', '').astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15876\3128332942.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df['Price'].str.replace('.', '').astype(int)

# %%
type(df['Price'][0])
# Out:
# numpy.int32

# %%
df.reset_index(drop = True, inplace = True)
df
# Out:
#       Year  Kilometers        Color Car Brand  Model   Price      City  \
# 0     2015      128000        Beyaz      Fiat  Linea  549000      Bolu
# 1     2017      225000        Beyaz      Fiat  Linea  550000      Bolu
# 2     2017       66816  Gri (Gümüş)      Fiat  Linea  509750    Samsun
# 3     2017      239000        Beyaz      Fiat  Linea  429950     İzmir
# 4     2016      490000        Beyaz      Fiat  Linea  350000  İstanbul
# ...    ...         ...          ...       ...    ...     ...       ...
# 2199  2014       26200        Beyaz      Fiat  Linea  535000   Kayseri
# 2200  2014      223000        Beyaz      Fiat  Linea  435000   Çankırı
# 2201  2016      150000        Beyaz      Fiat  Linea  350000     Muğla
# 2202  2013      191000        Beyaz      Fiat  Linea  455000   Kocaeli
# 2203  2015      250000        Beyaz      Fiat  Linea  430000   Malatya
#
#           District  Engine
# 0           Merkez     1.3
# 1           Merkez     1.3
# 2          İlkadım     1.4
# 3         Gaziemir     1.3
# 4         Bağcılar     1.3
# ...            ...     ...
# 2199     Melikgazi     1.4
# 2200        Merkez     1.3
# 2201       Dalaman     1.3
# 2202      Çayırova     1.3
# 2203    Battalgazi     1.3
#
# [2204 rows x 9 columns]

# %%
df.to_csv('car-sale-fiat-linea.csv', index = False)
