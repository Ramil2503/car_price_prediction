# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('final_data5.csv')
df
# Out:
#        Kilometers           Color   Car Brand     Model     Price  Engine  \
# 0         82000.0           Beyaz  Volkswagen      Polo  869900.0    1.60
# 1        260000.0           Beyaz     Renault      Clio  270000.0    1.40
# 2        361000.0   Gri (metalik)  Volkswagen      Golf  340000.0    1.60
# 3        163000.0             Gri        Fiat     Linea  505000.0    1.30
# 4         48800.0           Beyaz        Fiat      Egea  775000.0    1.30
# ...           ...             ...         ...       ...       ...     ...
# 14294    155000.0  Gri (titanyum)     Citroen  C-Elysee  605000.0    1.20
# 14295    113000.0             Gri  Volkswagen      Golf  940000.0    1.00
# 14296    235000.0           Beyaz        Fiat      Egea  575000.0    1.30
# 14297    131393.0            Mavi  Volkswagen      Golf  625000.0    1.60
# 14298    165000.0        Lacivert        Ford    Fiesta  190000.0    1.25
#
#        Vehicle Age
# 0              6.0
# 1             24.0
# ...

# %%
df.isnull().sum()
# Out:
# Kilometers     0
# Color          0
# Car Brand      0
# Model          0
# Price          0
# Engine         0
# Vehicle Age    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Vehicle Age'], df['Price'])

# %%
sns.histplot(df['Vehicle Age'], kde = True)
# Out:
# <AxesSubplot:xlabel='Vehicle Age', ylabel='Count'>

# %%
df['Vehicle Age'].mean()
# Out:
# 12.519057276732639

# %%
df.hist('Vehicle Age')
# Out:
# array([[<AxesSubplot:title={'center':'Vehicle Age'}>]], dtype=object)

# %%
df.boxplot('Vehicle Age', vert = False)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
Data = df['Vehicle Age']
q1 = np.percentile(Data, 25)
q3 = np.percentile(Data, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
data_no_outliers = Data[(Data >= lower_bound) & (Data <= upper_bound)]
df['Vehicle Age'] = data_no_outliers
df.boxplot(column = ['Vehicle Age'], grid = False, vert = False)
# Out:
# <AxesSubplot:>

# %%
# Replace missing values with a default value or any suitable strategy
default_value = 0  # You can replace 0 with any other suitable default value
df['Vehicle Age'].fillna(value=default_value, inplace=True)

df['Vehicle Age'].replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.dropna(subset = 'Vehicle Age', inplace = True)

# %%
df.isnull().sum()
# Out:
# Kilometers     0
# Color          0
# Car Brand      0
# Model          0
# Price          0
# Engine         0
# Vehicle Age    0
# dtype: int64

# %%
df.boxplot('Engine', vert = False)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
Data = df['Engine']
q1 = np.percentile(Data, 25)
q3 = np.percentile(Data, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
data_no_outliers = Data[(Data >= lower_bound) & (Data <= upper_bound)]
df['Engine'] = data_no_outliers
df.boxplot(column = ['Engine'], grid = False, vert = False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 6))

df_autox = pd.DataFrame(df.groupby(['Car Brand'])['Price'].mean().sort_values(ascending = False))
df_autox.plot.bar()
plt.title('Car Company Name vs Average Price')
plt.show()

# %%
df
# Out:
#        Kilometers           Color   Car Brand     Model     Price  Engine  \
# 0         82000.0           Beyaz  Volkswagen      Polo  869900.0    1.60
# 1        260000.0           Beyaz     Renault      Clio  270000.0    1.40
# 2        361000.0   Gri (metalik)  Volkswagen      Golf  340000.0    1.60
# 3        163000.0             Gri        Fiat     Linea  505000.0    1.30
# 4         48800.0           Beyaz        Fiat      Egea  775000.0    1.30
# ...           ...             ...         ...       ...       ...     ...
# 14294    155000.0  Gri (titanyum)     Citroen  C-Elysee  605000.0    1.20
# 14295    113000.0             Gri  Volkswagen      Golf  940000.0    1.00
# 14296    235000.0           Beyaz        Fiat      Egea  575000.0    1.30
# 14297    131393.0            Mavi  Volkswagen      Golf  625000.0    1.60
# 14298    165000.0        Lacivert        Ford    Fiesta  190000.0    1.25
#
#        Vehicle Age
# 0              6.0
# 1             24.0
# ...

# %%
df.boxplot('Kilometers', vert = False)
# Out:
# <AxesSubplot:>

# %%
df['Kilometers'].median()
# Out:
# 181000.0

# %%
import numpy as np
Data = df['Kilometers']
q1 = np.percentile(Data, 25)
q3 = np.percentile(Data, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
data_no_outliers = Data[(Data >= lower_bound) & (Data <= upper_bound)]
df['Kilometers'] = data_no_outliers
df.boxplot(column = ['Kilometers'], grid = False, vert = False)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#        Kilometers           Color   Car Brand     Model     Price  Engine  \
# 0         82000.0           Beyaz  Volkswagen      Polo  869900.0    1.60
# 1        260000.0           Beyaz     Renault      Clio  270000.0    1.40
# 2        361000.0   Gri (metalik)  Volkswagen      Golf  340000.0    1.60
# 3        163000.0             Gri        Fiat     Linea  505000.0    1.30
# 4         48800.0           Beyaz        Fiat      Egea  775000.0    1.30
# ...           ...             ...         ...       ...       ...     ...
# 14294    155000.0  Gri (titanyum)     Citroen  C-Elysee  605000.0    1.20
# 14295    113000.0             Gri  Volkswagen      Golf  940000.0    1.00
# 14296    235000.0           Beyaz        Fiat      Egea  575000.0    1.30
# 14297    131393.0            Mavi  Volkswagen      Golf  625000.0    1.60
# 14298    165000.0        Lacivert        Ford    Fiesta  190000.0    1.25
#
#        Vehicle Age
# 0              6.0
# 1             24.0
# ...

# %%
sns.histplot('Price', kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.boxplot(df['Price'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
import numpy as np
Data = df['Price']
q1 = np.percentile(Data, 25)
q3 = np.percentile(Data, 75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
data_no_outliers = Data[(Data >= lower_bound) & (Data <= upper_bound)]
df['Price'] = data_no_outliers
df.boxplot(column = ['Price'], grid = False, vert = False)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#        Kilometers           Color   Car Brand     Model     Price  Engine  \
# 0         82000.0           Beyaz  Volkswagen      Polo  869900.0    1.60
# 1        260000.0           Beyaz     Renault      Clio  270000.0    1.40
# 2        361000.0   Gri (metalik)  Volkswagen      Golf  340000.0    1.60
# 3        163000.0             Gri        Fiat     Linea  505000.0    1.30
# 4         48800.0           Beyaz        Fiat      Egea  775000.0    1.30
# ...           ...             ...         ...       ...       ...     ...
# 14294    155000.0  Gri (titanyum)     Citroen  C-Elysee  605000.0    1.20
# 14295    113000.0             Gri  Volkswagen      Golf  940000.0    1.00
# 14296    235000.0           Beyaz        Fiat      Egea  575000.0    1.30
# 14297    131393.0            Mavi  Volkswagen      Golf  625000.0    1.60
# 14298    165000.0        Lacivert        Ford    Fiesta  190000.0    1.25
#
#        Vehicle Age
# 0              6.0
# 1             24.0
# ...

# %%
sns.histplot(df['Price'], kde = True)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
df.dropna(subset = 'Price', inplace = True)

# %%
median_kilometers = df['Kilometers'].median()
df['Kilometers'].fillna(median_kilometers, inplace=True)

# %%
sns.histplot(df['Kilometers'], kde = True)
# Out:
# <AxesSubplot:xlabel='Kilometers', ylabel='Count'>

# %%
median_engine = df['Engine'].median()
df["Engine"].fillna(median_engine, inplace = True)

# %%
df.isnull().sum()
# Out:
# Kilometers     0
# Color          0
# Car Brand      0
# Model          0
# Price          0
# Engine         0
# Vehicle Age    0
# dtype: int64

# %%
df
# Out:
#        Kilometers           Color   Car Brand     Model     Price  Engine  \
# 0         82000.0           Beyaz  Volkswagen      Polo  869900.0    1.60
# 1        260000.0           Beyaz     Renault      Clio  270000.0    1.40
# 2        361000.0   Gri (metalik)  Volkswagen      Golf  340000.0    1.60
# 3        163000.0             Gri        Fiat     Linea  505000.0    1.30
# 4         48800.0           Beyaz        Fiat      Egea  775000.0    1.30
# ...           ...             ...         ...       ...       ...     ...
# 14294    155000.0  Gri (titanyum)     Citroen  C-Elysee  605000.0    1.20
# 14295    113000.0             Gri  Volkswagen      Golf  940000.0    1.00
# 14296    235000.0           Beyaz        Fiat      Egea  575000.0    1.30
# 14297    131393.0            Mavi  Volkswagen      Golf  625000.0    1.60
# 14298    165000.0        Lacivert        Ford    Fiesta  190000.0    1.25
#
#        Vehicle Age
# 0              6.0
# 1             24.0
# ...

# %%
# df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#        Kilometers           Color   Car Brand     Model     Price  Engine  \
# 0         82000.0           Beyaz  Volkswagen      Polo  869900.0    1.60
# 1        260000.0           Beyaz     Renault      Clio  270000.0    1.40
# 2        361000.0   Gri (metalik)  Volkswagen      Golf  340000.0    1.60
# 3        163000.0             Gri        Fiat     Linea  505000.0    1.30
# 4         48800.0           Beyaz        Fiat      Egea  775000.0    1.30
# ...           ...             ...         ...       ...       ...     ...
# 14294    155000.0  Gri (titanyum)     Citroen  C-Elysee  605000.0    1.20
# 14295    113000.0             Gri  Volkswagen      Golf  940000.0    1.00
# 14296    235000.0           Beyaz        Fiat      Egea  575000.0    1.30
# 14297    131393.0            Mavi  Volkswagen      Golf  625000.0    1.60
# 14298    165000.0        Lacivert        Ford    Fiesta  190000.0    1.25
#
#        Vehicle Age
# 0              6.0
# 1             24.0
# ...

# %%
df['Vehicle Age'] = df['Vehicle Age'].astype(int)

# %%
df['Kilometers'] = df['Kilometers'].astype(int)

# %%
# df.to_csv('final_data7.csv', index = False)

# %%
from sklearn.preprocessing import OrdinalEncoder
categorical_cols = ['Color', 'Car Brand', 'Model']

# Initialize the OrdinalEncoder
ordinal_encoder = OrdinalEncoder()

# Apply OrdinalEncoder to the specified columns
df[categorical_cols] = ordinal_encoder.fit_transform(df[categorical_cols])

# %%
df
# Out:
#        Kilometers  Color  Car Brand  Model     Price  Engine  Vehicle Age
# 0           82000    2.0        7.0   26.0  869900.0    1.60            6
# 1          260000    2.0        5.0   16.0  270000.0    1.40           24
# 2          361000    8.0        7.0   24.0  340000.0    1.60           27
# 3          163000    6.0        2.0   25.0  505000.0    1.30           12
# 4           48800    2.0        2.0   19.0  775000.0    1.30            2
# ...           ...    ...        ...    ...       ...     ...          ...
# 14294      155000    9.0        1.0   10.0  605000.0    1.20            5
# 14295      113000    6.0        7.0   24.0  940000.0    1.00            5
# 14296      235000    2.0        2.0   19.0  575000.0    1.30            6
# 14297      131393   13.0        7.0   24.0  625000.0    1.60           16
# 14298      165000   12.0        3.0   21.0  190000.0    1.25           23
#
# [14221 rows x 7 columns]

# %%
# df.to_csv('car_prediction6.csv', index = False)

# %%
X = df.drop('Price', axis=1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)
print(y_lr_train_pred, y_lr_test_pred)
# Out:
# [384181.78681081 613244.73674809 547396.5915678  ... 584211.27446499
#  577815.45589069 734921.03242956] [488078.07767836 548111.14514391 495116.33777648 ... 680552.55374632
#  555889.81230751 624493.58034633]

# %%
residuals_train = y_train - y_lr_train_pred
residuals_test = y_test - y_lr_test_pred

# Plot residuals
plt.figure(figsize=(10, 6))
plt.scatter(y_lr_train_pred, residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(y_lr_test_pred, residuals_test, c='green', marker='s', label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score (y_train, y_lr_train_pred)
lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  11426856637.972956
# LR R2 (Train):  0.6538682196084542
# LR MSE (Test):  10211609847.298
# LR R2 (Test):  0.664063698370865

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)
print(y_rf_train_pred, y_rf_test_pred)
# Out:
# [355630.         851009.         519405.83333333 ... 641040.
#  498830.         727130.        ] [445481.5        525970.         482451.5        ... 776543.98
#  584413.         730492.02380952]

# %%
from sklearn.metrics import mean_squared_error, r2_score
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score (y_train, y_rf_train_pred)
rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
residuals_train = y_train - y_rf_train_pred
residuals_test = y_test - y_rf_test_pred

# Plot residuals
plt.figure(figsize=(10, 6))
plt.scatter(y_rf_train_pred, residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(y_rf_test_pred, residuals_test, c='green', marker='s', label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
print('RF MSE (Train): ', rf_train_mse)
print('RF R2 (Train): ', rf_train_r2)
print('RF MSE (Test): ', rf_test_mse)
print('R2 (Test): ', rf_test_r2)
# Out:
# RF MSE (Train):  654560333.7730478
# RF R2 (Train):  0.9801726633246061
# RF MSE (Test):  3937680042.841163
# R2 (Test):  0.8704602222008188

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_dt_train_pred = dt.predict(X_train)
y_dt_test_pred = dt.predict(X_test)
print(y_dt_train_pred, y_dt_test_pred)
# Out:
# [355000. 865000. 490000. ... 670000. 499750. 745000.] [420000. 539000. 484500. ... 675000. 515000. 737500.]

# %%
from sklearn.metrics import mean_squared_error, r2_score
dt_train_mse = mean_squared_error(y_train, y_dt_train_pred)
dt_train_r2 = r2_score (y_train, y_dt_train_pred)
dt_test_mse = mean_squared_error(y_test, y_dt_test_pred)
dt_test_r2 = r2_score(y_test, y_dt_test_pred)

# %%
residuals_train = y_train - y_dt_train_pred
residuals_test = y_test - y_dt_test_pred

# Plot residuals
plt.figure(figsize=(10, 6))
plt.scatter(y_dt_train_pred, residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(y_dt_test_pred, residuals_test, c='green', marker='s', label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
print('DT MSE (Train): ',dt_train_mse)
print('DT R2 (Train): ', dt_train_r2)
print('DT MSE (Test): ', dt_test_mse)
print('R2 (Test): ', dt_test_r2)
# Out:
# DT MSE (Train):  96012961.78997011
# DT R2 (Train):  0.9970916640981922
# DT MSE (Test):  6890659977.089768
# R2 (Test):  0.7733146033678577

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
y_ridge_train_pred = ridge.predict(X_train)
y_ridge_test_pred = ridge.predict(X_test)
print(y_ridge_train_pred, y_ridge_test_pred)
# Out:
# [384310.18871024 613243.89989646 547554.29720733 ... 584091.85953319
#  578042.45888315 734749.03283916] [488098.40577767 548199.92712501 495097.91867615 ... 680799.06465498
#  555733.4700122  624326.36142654]

# %%
from sklearn.metrics import mean_squared_error, r2_score
ridge_train_mse = mean_squared_error(y_train, y_ridge_train_pred)
ridge_train_r2 = r2_score (y_train, y_ridge_train_pred)
ridge_test_mse = mean_squared_error(y_test, y_ridge_test_pred)
ridge_test_r2 = r2_score(y_test, y_ridge_test_pred)

# %%
print('RR MSE (Train): ',ridge_train_mse)
print('RR R2 (Train): ', ridge_train_r2)
print('RR MSE (Test): ', ridge_test_mse)
print('R2 (Test): ', ridge_test_r2)
# Out:
# RR MSE (Train):  11426878818.103415
# RR R2 (Train):  0.6538675477484417
# RR MSE (Test):  10213056012.75999
# R2 (Test):  0.6640161231614602

# %%
residuals_train = y_train - y_ridge_train_pred
residuals_test = y_test - y_ridge_test_pred

# Plot residuals
plt.figure(figsize=(10, 6))
plt.scatter(y_ridge_train_pred, residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(y_ridge_test_pred, residuals_test, c='green', marker='s', label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_svr_train_pred = svr.predict(X_train)
y_svr_test_pred = svr.predict(X_test)

# %%
print(y_svr_train_pred)
print(y_svr_test_pred)
# Out:
# [548745.4060846  550468.75404007 549341.86758635 ... 550341.46481878
#  551182.89960181 550926.91937463]
# [551540.26875538 551367.97255685 548563.29661408 ... 552284.33501456
#  550046.04089016 550150.98058966]

# %%
from sklearn.metrics import mean_squared_error, r2_score
svr_train_mse = mean_squared_error(y_train, y_svr_train_pred)
svr_train_r2 = r2_score (y_train, y_svr_train_pred)
svr_test_mse = mean_squared_error(y_test, y_svr_test_pred)
svr_test_r2 = r2_score(y_test, y_svr_test_pred)

# %%
print('SVR MSE (Train): ',svr_train_mse)
print('SVR R2 (Train): ', svr_train_r2)
print('SVR MSE (Test): ', svr_test_mse)
print('SVR (Test): ', svr_test_r2)
# Out:
# SVR MSE (Train):  32892711764.915737
# SVR R2 (Train):  0.0036443751939917446
# SVR MSE (Test):  30292824355.47098
# SVR (Test):  0.0034422062677408327

# %%
residuals_train = y_train - y_svr_train_pred
residuals_test = y_test - y_svr_test_pred

# Plot residuals
plt.figure(figsize=(10, 6))
plt.scatter(y_svr_train_pred, residuals_train, c='blue', marker='o', label='Training data')
plt.scatter(y_svr_test_pred, residuals_test, c='green', marker='s', label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
from sklearn.model_selection import learning_curve

best_params = {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}

# Define the RandomForestRegressor with the best parameters
best_rf = RandomForestRegressor(**best_params)
best_rf.fit(X_train, y_train)
# Generate learning curves
train_sizes, train_scores, test_scores = learning_curve(best_rf, X, y, cv=5, 
                                                        train_sizes=np.linspace(0.1, 1.0, 10),
                                                        scoring='r2')

# Calculate mean and standard deviation of training and test scores
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot learning curves
plt.figure(figsize=(10, 6))
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
         label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
         label="Cross-validation score")
plt.xlabel("Training examples")
plt.ylabel("Score")
plt.legend(loc="best")
plt.title("Learning Curve (RandomForestRegressor)")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression()
lgr.fit(X_train, y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_lgr_train_pred = svr.predict(X_train)
y_lgr_test_pred = svr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
lgr_train_mse = mean_squared_error(y_train, y_lgr_train_pred)
lgr_train_r2 = r2_score (y_train, y_lgr_train_pred)
lgr_test_mse = mean_squared_error(y_test, y_lgr_test_pred)
lgr_test_r2 = r2_score(y_test, y_lgr_test_pred)

# %%
print('LGR MSE (Train): ',lgr_train_mse)
print('LGR R2 (Train): ', lgr_train_r2)
print('LGR MSE (Test): ', lgr_test_mse)
print('LGR (Test): ', lgr_test_r2)
# Out:
# LGR MSE (Train):  32892711764.915737
# LGR R2 (Train):  0.0036443751939917446
# LGR MSE (Test):  30292824355.47098
# LGR (Test):  0.0034422062677408327
